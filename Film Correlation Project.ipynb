# %%
#libraries
import numpy as np

import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
#read in data

df = pd.read_csv('movies.csv')

# %%
#preview data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#check for missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#drop null values
df = df.dropna(axis=0)

# %%
#check for missing data once again
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#find data types for columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#remove decimal from columns by changing their data type
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
#check to ensure decimal removal went through
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#1) split the value in the 'released' column by the open parenthesis
#2) keep the first element of the list after step 1, meaning the date part of the string
#3) convert the string value into a datetime value
df['released'] = pd.to_datetime(df['released'].str.split('(').str[0])
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score      votes         director                   writer  \
# 0 1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1 1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2 1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3 1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4 1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# ...

# %%
#create a new column that takes the year value of the 'released' column
df['correctedyear'] = df['released'].apply(lambda x:x.year)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score      votes         director                   writer  \
# 0 1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1 1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2 1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3 1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4 1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# ...

# %%
#sort the data by gross revenue and save the result as the new dataframe
df = df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#        released  score      votes       director              writer  \
# 5445 2009-12-18    7.8  1100000.0  James Cameron       James Cameron
# 7445 2019-04-26    8.4   903000.0  Anthony Russo  Christopher Markus
# 3045 1997-12-19    7.8  1100000.0  James Cameron       James Cameron
# 6663 2015-12-18    7.8   876000.0    J.J. Abrams     Lawrence Kasdan
# 7244 2018-04-27    8.4   897000.0  Anthony Russo  Christopher Markus
#
#                    star        country     budget       gross  \
# 5445    Sam Worthington  United States  237000000  2847246203
# ...

# %%
#Predictions:
#budget/gross = high corr
#company/gross = high corr

# %%
#matplotlib plot

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings')

plt.show()

# %%
#seaborn plot

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'red'}, line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#correlation matrix for all numeric columns in the dataset
df.corr(method='pearson')
# Out:
#                    year     score     votes    budget     gross   runtime  \
# year           1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score          0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes          0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget         0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross          0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime        0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# correctedyear  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#                correctedyear
# year                0.998726
# score               0.061923
# votes               0.203098
# budget              0.320312
# gross               0.268721
# runtime             0.075294
# correctedyear       1.000000

# %%
#heatmap for matrix above
corrmat = df.corr(method='pearson')

sns.heatmap(corrmat, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
#assigning a numeric value for each categorical column
rank = df

for col in rank.columns:
    if (rank[col].dtype=='object'):
        rank[col] = rank[col].astype('category')
        rank[col] = rank[col].cat.codes

rank.head()
# Out:
#       name  rating  genre  year   released  score      votes  director  \
# 5445   386       5      0  2009 2009-12-18    7.8  1100000.0       785
# 7445   388       5      0  2019 2019-04-26    8.4   903000.0       105
# 3045  4909       5      6  1997 1997-12-19    7.8  1100000.0       785
# 6663  3643       5      0  2015 2015-12-18    7.8   876000.0       768
# 7244   389       5      0  2018 2018-04-27    8.4   897000.0       105
#
#       writer  star  country     budget       gross  company  runtime  \
# 5445    1263  1534       47  237000000  2847246203     1382    162.0
# 7445     513  1470       47  356000000  2797501328      983    181.0
# 3045    1263  1073       47  200000000  2201647264     1382    194.0
# 6663    1806   356       47  245000000  2069521700      945    138.0
# 7244     513  1470       47  321000000  2048359754      983    149.0
#
#       correctedyear
# 5445           2009
# 7445           2019
# 3045           1997
# 6663           2015
# ...

# %%
#correlation matrix for all columns in the dataset
rank.corr()
# Out:
#                    name    rating     genre      year     score     votes  \
# name           1.000000 -0.029234  0.010996  0.025542  0.014450  0.012615
# rating        -0.029234  1.000000  0.147796  0.019499  0.065983  0.006031
# genre          0.010996  0.147796  1.000000 -0.073167  0.035106 -0.135990
# year           0.025542  0.019499 -0.073167  1.000000  0.056386  0.206021
# score          0.014450  0.065983  0.035106  0.056386  1.000000  0.474256
# votes          0.012615  0.006031 -0.135990  0.206021  0.474256  1.000000
# director       0.015246  0.014656 -0.008553 -0.038354  0.005413 -0.010376
# writer         0.012880 -0.003149  0.017578 -0.025908  0.012843 -0.005316
# star          -0.006882  0.009196  0.003341 -0.032157  0.007296 -0.017638
# country       -0.025490  0.008230 -0.009164 -0.066748 -0.043051  0.041551
# budget         0.023392 -0.203946 -0.368523  0.327722  0.072001  0.439675
# gross          0.005639 -0.181906 -0.244101  0.274321  0.222556  0.614751
# ...

# %%
#heatmap for matrix above (including categorical columns)
corrmat = rank.corr(method='pearson')

sns.heatmap(corrmat, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
#unstacking correlation values from the matrix
corrpairs = corrmat.unstack()
corrpairs
# Out:
# name           name             1.000000
#                rating          -0.029234
#                genre            0.010996
#                year             0.025542
#                score            0.014450
#                                   ...
# correctedyear  budget           0.320312
#                gross            0.268721
#                company         -0.018806
#                runtime          0.075294
#                correctedyear    1.000000
# Length: 225, dtype: float64

# %%
#sorting the unstacked matrix by value pairs
sortedpairs=corrpairs.sort_values()
sortedpairs
# Out:
# genre          budget          -0.368523
# budget         genre           -0.368523
# gross          genre           -0.244101
# genre          gross           -0.244101
# rating         budget          -0.203946
#                                   ...
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# correctedyear  correctedyear    1.000000
# Length: 225, dtype: float64

# %%
#filtering out pairs to find those that have a high correlation value 
highcorr=sortedpairs[(sortedpairs)>.5]
highcorr
# Out:
# gross          votes            0.614751
# votes          gross            0.614751
# gross          budget           0.740247
# budget         gross            0.740247
# year           correctedyear    0.998726
# correctedyear  year             0.998726
# name           name             1.000000
# writer         writer           1.000000
# company        company          1.000000
# gross          gross            1.000000
# budget         budget           1.000000
# country        country          1.000000
# star           star             1.000000
# director       director         1.000000
# votes          votes            1.000000
# score          score            1.000000
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# correctedyear  correctedyear    1.000000
# dtype: float64

# %%
#Predictions:
#budget/gross = high corr
#company/gross = high corr

#Results:
#votes and budget have the highest correlation to gross earnings

#company does not have a significantly high correlation to gross earnings
